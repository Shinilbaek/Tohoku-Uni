# %% [markdown]
# <font size='5'>**Data Science Training Camp I Practice Workbook**</font>

# %% [markdown]
# <u>Based on [Samy Baladram's Lesson](https://sites.google.com/tohoku.ac.jp/gpds-course/courses/training-camp-i), International Liasion Office-GSIS-Tohoku University.</u>
#
# Last Updated by [Shinil](mailto:baisy1999@outlook.com):21-11-03

# %% [markdown]
# <font size='3' color="#bb2222">**!**</font>&nbsp;&nbsp;<font size='2'>**To retrieve the necessary data and libraries, please run the following code first.**</font></font><br>

# %%
# Students Dataset (See details at https://archive.ics.uci.edu/ml/datasets/Student+Performance )
# !curl https://dl.dropboxusercontent.com/s/ijh78s1bxm7kctv/gp_data.csv -so gp_data.csv
# !curl https://dl.dropboxusercontent.com/s/1770hoabg1utoat/gp_grades.csv -so gp_grades.csv
# !curl https://dl.dropboxusercontent.com/s/ymjz6vqjw3jg4e7/ms_data.csv -so ms_data.csv
# !curl https://dl.dropboxusercontent.com/s/k1howfpyp5rmgnb/ms_grades.csv -so ms_grades.csv

# Cars Dataset
# !curl https://dl.dropboxusercontent.com/s/hk2hc86ml3tvkyh/imports-85.data -so cars.csv
# !curl https://dl.dropboxusercontent.com/s/7d4wkkzicw0xtaz/test-data.csv -so car_test_data.csv
# !curl https://dl.dropboxusercontent.com/s/v9gmgxupkypn5dw/train-data.csv -so car_train_data.csv

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import timeit
import seaborn as sns
import sklearn as sl

print("Loading Success")

# %% [markdown]
# ### <font size='6'>**Lesson 1**</font>

# %% [markdown]
# This lesson covers the basics of the pandas library and pandas DataFrame. First, we will learn how to read data from a file into a DataFrame. We will then look at functions that we can use to become more familiar with the data. Finally, we will introduce methods for selecting subsets of data.
#
# We will use a dataset that contains demographic, social, and educational information on students in a Portuguese school.

# %% [markdown]
# #### <font size='5'>1.1 &nbsp;Anatomy of a DataFrame</font>
#
# In order to work with our data, we need to load it into a DataFrame. After loading the data, it is a good idea to examine the DataFrame and make sure everything was loaded as expected. If not, then we can do simple preprocessing like renaming.
#
# <font color="#6AA74F" size='3'>**1**&nbsp;&nbsp; </font> Load the file <tt>gp_data.csv</tt> into a DataFrame. Use semicolons for field separators and use the column <tt>student_id</tt> as the index.
#
# <font color="#6AA74F" size='3'>**2**&nbsp;&nbsp; </font>
# Make sure the DataFrame looks right by printing the first and last 5 rows of the data.
#
# <font color="#6AA74F" size='3'>**3**&nbsp;&nbsp; </font>
# Make sure that <tt>student_id</tt> was used for the index by printing the index of the dataframe.
#
# <font color="#6AA74F" size='3'>**4**&nbsp;&nbsp; </font>
# Make sure that a row of data was not accidentally used in place of column names by printing the columns of the DataFrame.
#
# <font color="#6AA74F" size='3'>**5**&nbsp;&nbsp; </font>
# Check the number of rows and columns in the dataframe by printing its shape.
#
# <font color="#6AA74F" size='3'>**6**&nbsp;&nbsp; </font>
# Modify the labels in the index so that all characters are lowercase. Print the result.
#
# <font color="#6AA74F" size='3'>**7**&nbsp;&nbsp; </font>
# Some column names are the shortened versions of their original meaning and are unclear. E.g. <tt>Pstatus</tt> is <tt>parent's cohabitation status</tt>. By referring [here](https://archive.ics.uci.edu/ml/datasets/Student+Performance),  rename <tt>Medu, Fedu, Dalc,</tt> and <tt>Walc</tt> to something more appropriate. Print the renamed columns.

# %%
import pandas as pd
print("# 1 (No out put)")
data = pd.read_csv('gp_data.csv',sep=';',index_col='student_id')

print("\n# 2")
print(data.head(5))
print('\n')
print(data.tail(5))

print("\n# 3")
print(data.index)

print("\n# 4")
print(data.columns)

print("\n# 5")
print(data.shape)

print("\n# 6")
print(data.rename(columns=str.lower).columns)

print("\n# 7")
clear_labels ={'Pstatus':"parent's cohabitation status",
              'Fedu':"father's education",
              'Medu' : "mother's education",
              'Dalc' : 'workday alcohol consumption',
              'Walc' : 'weekend alcohol consumption'}
print(data.rename(columns=clear_labels).columns)
# Out:
# # 1 (No out put)
#
# # 2
#            sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# student_id
# GP9139       F   18       U     GT3       A     4     4  at_home   teacher
# GP1565       F   17       U     GT3       T     1     1  at_home     other
# GP8154       F   15       U     LE3       T     1     1  at_home     other
# GP9418       F   15       U     GT3       T     4     2   health  services
# GP3416       F   16       U     GT3       T     3     3    other     other
#
#             reason  ... higher  internet  romantic  famrel freetime goout  \
# student_id          ...
# GP9139      course  ...    yes        no        no       4        3     4
# GP1565      course  ...    yes       yes        no       5        3     3
# GP8154       other  ...    yes       yes        no       4        3     2
# GP9418        home  ...    yes       yes       yes       3        2     2
# GP3416        home  ...    yes        no        no       4        3     2
#
# ...

# %% [markdown]
# <font size='2' color="#A7AFBC">**EXPECTED OUTPUT**</font>
# ![Screen Shot 2021-10-21 at 13.41.44-min.png](data:image/png;base64,...)

# %% [markdown]
# #### <font size='5'>1.2 &nbsp;Data Types Conversion</font>
#
# For all the following questions (other than no 2 & 3), print only the first 5 rows of the data.
#
# <font color="#6AA74F" size='3'>**1**&nbsp;&nbsp; </font>
# Check the data type of each column by printing the data types.
#
# <font color="#6AA74F" size='3'>**2**&nbsp;&nbsp; </font>
# Get a more concise summary of data types by printing each unique data type, and the number of columns using that data type.
#
# <font color="#6AA74F" size='3'>**3**&nbsp;&nbsp; </font>
# Some data does not require the full range of the default data type assigned by pandas. Change the data type of <tt>Age</tt> to <tt>int32</tt>, then print the column's data type to make sure the change was successful.
#
# <font color="#6AA74F" size='3'>**4**&nbsp;&nbsp; </font>
# Create dummy variables for column <tt>sex</tt>. Print the result.

# %%
print('#1')
print(data.dtypes.head(5))

print('#2')
print(data.dtypes.value_counts())

print('#3')
data_age = data['age']
print(data_age.astype('int32').dtypes)

print('#4')
data_sex_dum = pd.get_dummies(data,columns=['sex'])
print(data_sex_dum.head(5))
# Out:
# #1
# sex        object
# age         int64
# address    object
# famsize    object
# Pstatus    object
# dtype: object
# #2
# object    16
# int64     13
# dtype: int64
# #3
# int32
# #4
#             age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# student_id
# GP9139       18       U     GT3       A     4     4  at_home   teacher
# GP1565       17       U     GT3       T     1     1  at_home     other
# GP8154       15       U     LE3       T     1     1  at_home     other
# GP9418       15       U     GT3       T     4     2   health  services
# GP3416       16       U     GT3       T     3     3    other     other
#
#             reason guardian  ...  romantic  famrel  freetime goout Dalc Walc  \
# student_id                   ...
# GP9139      course   mother  ...        no       4         3     4    1    1
# GP1565      course   father  ...        no       5         3     3    1    1
# GP8154       other   mother  ...        no       4         3     2    2    3
# ...

# %% [markdown]
# <font size='2' color="#A7AFBC">**EXPECTED OUTPUT**</font>
# ![Screen Shot 2021-10-21 at 13.42.47-min.png](data:image/png;base64,...)

# %% [markdown]
# #### <font size='5'>1.3 &nbsp;Rows Selection</font>
#
# For all the following questions, print only the first 5 rows of the data.
#
# <font color="#6AA74F" size='3'>**1**&nbsp;&nbsp; </font>Use integer indexing to print the 10th row.
#
# <font color="#6AA74F" size='3'>**2**&nbsp;&nbsp; </font>Use integer indexing to print rows 50 to 60.
#
# <font color="#6AA74F" size='3'>**3**&nbsp;&nbsp; </font>Use integer indexing to print rows 0, 33, and 101.
#
# <font color="#6AA74F" size='3'>**4**&nbsp;&nbsp; </font>Use label indexing to print the row corresponding to the student with ID <tt>gp3915</tt>.

# %%
print('#1')
print(data.iloc[9].head(5))

print('#2')
print(data.iloc[50:60].head(5))

print('#3')
print(data.iloc[[0,33,101]].head(5))

print('#4')
print(data.loc['GP3915'].head(5))
# Out:
# #1
# sex          M
# age         15
# address      U
# famsize    GT3
# Pstatus      T
# Name: GP4650, dtype: object
# #2
#            sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# student_id
# GP3649       F   16       U     LE3       T     2     2  services  services
# GP4590       F   15       U     LE3       T     4     2    health     other
# GP9737       M   15       U     LE3       A     4     2    health    health
# GP0153       F   15       U     GT3       T     4     4  services  services
# GP3684       F   15       U     LE3       A     3     3     other     other
#
#             reason  ... higher  internet  romantic  famrel freetime goout  \
# student_id          ...
# GP3649      course  ...    yes       yes        no       4        3     3
# GP4590       other  ...    yes       yes        no       4        3     3
# GP9737       other  ...    yes        no        no       5        5     5
# ...

# %% [markdown]
# <font size='2' color="#A7AFBC">**EXPECTED OUTPUT**</font>
# ![Screen Shot 2021-10-21 at 13.43.12-min.png](data:image/png;base64,...)

# %% [markdown]
# #### <font size='5'>1.4 &nbsp;Columns Selection</font>
# For all the following questions, print only the first 5 rows of the data.
#
# <font color="#6AA74F" size='3'>**1**&nbsp;&nbsp; </font>Select and print the column <tt>absences</tt>.
#
# <font color="#6AA74F" size='3'>**2**&nbsp;&nbsp; </font>Using row and column selection, print the columns <tt>internet</tt> and <tt>goout</tt> for the last 10 rows.
#
# <font color="#6AA74F" size='3'>**3**&nbsp;&nbsp; </font>Using row and column selection, print the columns <tt>sex</tt> and <tt>age</tt> for students <tt>gp1592, gp0281,</tt> and <tt>gp4248</tt>.
#
# <font color="#6AA74F" size='3'>**4**&nbsp;&nbsp; </font>Print all columns having a dtype of <tt>object</tt>.
#
# <font color="#6AA74F" size='3'>**5**&nbsp;&nbsp; </font>Print all columns with the word <tt>time</tt> in the column title.

# %%
print('#1')
data_ab = data['absences']
print(data_ab.head(5))

print('\n#2')
data_ig = data[['internet','goout']]
print(data_ig.iloc[-10:].head(5))

print('\n#3')
data_sa = data[['sex','age']]
print(data_sa.loc[['GP1592','GP0281','GP4248']])

print('\n#4')
print(data.select_dtypes(include=['object']).head(5))

print('\n#5')
print(data.filter(like='time').head(5))
# Out:
# #1
# student_id
# GP9139    4
# GP1565    2
# GP8154    6
# GP9418    0
# GP3416    0
# Name: absences, dtype: int64
#
# #2
#            internet  goout
# student_id
# GP6593          yes      3
# GP1647          yes      2
# GP1744          yes      5
# GP2990          yes      4
# GP9880          yes      4
#
# #3
#            sex  age
# student_id
# GP1592       F   18
# GP0281       F   17
# GP4248       F   17
#
# #4
#            sex address famsize Pstatus     Mjob      Fjob  reason guardian  \
# student_id
# GP9139       F       U     GT3       A  at_home   teacher  course   mother
# GP1565       F       U     GT3       T  at_home     other  course   father
# GP8154       F       U     LE3       T  at_home     other   other   mother
# GP9418       F       U     GT3       T   health  services    home   mother
# GP3416       F       U     GT3       T    other     other    home   father
#
#            schoolsup famsup paid activities nursery higher internet romantic
# student_id
# ...

# %% [markdown]
# <font size='2' color="#A7AFBC">**EXPECTED OUTPUT**</font>
# ![Screen Shot 2021-10-21 at 13.43.28-min.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ### <font size='6'>**Lesson 2**&nbsp;&nbsp;</font>

# %% [markdown]
# When performing data analysis, we may want to only look at data that matches a certain condition. Additionally, we also could perform the same calculations on groups of data. Lesson 2 introduces methods for filtering and grouping, and ends with a section on combining data.
#
# We will use the same data set as in Lesson 1. Make sure to reload the DataFrame so that any changes made in the previous lesson do not carry over.

# %% [markdown]
# #### <font size='5'>2.1 &nbsp;Filtering with Boolean</font>

# %% [markdown]
# For all the following questions, print only the first 5 rows of the data.
#
# <font color="#6AA74F" size='3'>**1**&nbsp;&nbsp; </font>Let's select students who have perfect attendance records:
#  * Create a boolean array corresponding to students who have no absences.
#  * Print the array.
#  * Print rows that meet the boolean condition.
#
# <font color="#6AA74F" size='3'>**2**&nbsp;&nbsp; </font>Let's select students whose parents both have higher education:
#  * Create a boolean array for students whose mothers have higher education.
#  * Create a boolean array for students whose fathers have higher education.
#  * Create a third array for students whose parents BOTH have higher education.
#  * Print rows that meet the condition in the third array.
#
# <font color="#6AA74F" size='3'>**3**&nbsp;&nbsp; </font>Find students who have been absent at least once, and have at least one parent with higher education:
#  * Create a boolean array for students who have been absent at least once
#  * Create a boolean array for students who have at least one parent with higher education.
#  * Print rows for students who who have been absent at least once, and have at least one parent with higher education.
# <br>*Hint*: Use the logical operators <tt>not</tt> and <tt>or</tt> and reuse the arrays from #1 and #2.

# %% [markdown]
# <font size='2' color="#A7AFBC">**EXPECTED OUTPUT**</font>
# ![Screen Shot 2021-10-21 at 13.59.16-min.png](data:image/png;base64,...)

# %% [markdown]
# #### <font size='5'>2.2 &nbsp;Grouping Object</font>

# %% [markdown]
# <font color="#6AA74F" size='3'>**1**&nbsp;&nbsp; </font>Create a <tt>groupby</tt> object for the column <tt>age</tt>. Then, print the number of groups.
#
# <font color="#6AA74F" size='3'>**2**&nbsp;&nbsp; </font>Get additional details on the groups by printing the size of each group.
#
# <font color="#6AA74F" size='3'>**3**&nbsp;&nbsp; </font>Print the first data occurrence in each group.
#
# <font color="#6AA74F" size='3'>**4**&nbsp;&nbsp; </font>Select and print the 18 year-old group. (First 5 rows only)
#
# <font color="#6AA74F" size='3'>**5**&nbsp;&nbsp; </font>We can also group by multiple columns. Group by both <tt>sex</tt> and <tt>age</tt> and print the 18 year-old female group.

# %% [markdown]
# <font size='2' color="#A7AFBC">**EXPECTED OUTPUT**</font>
# ![Screen Shot 2021-10-21 at 13.59.27-min.png](data:image/png;base64,...)

# %% [markdown]
# #### <font size='5'>2.3 &nbsp;Aggregation</font>

# %% [markdown]
# Being able to group data allows us to perform calculations that may have interesting results. In this exercise we will group by address (U = urban and R = rural) and apply some useful functions.
#
# <font color="#6AA74F" size='3'>**1**&nbsp;&nbsp; </font>See which group of students has parents with higher education. Group by <tt>address</tt> and print the means of <tt>Medu</tt> and <tt>Fedu</tt>.
#
# <font color="#6AA74F" size='3'>**2**&nbsp;&nbsp; </font>See which group of students has higher variation in their travel time. Group by <tt>address</tt> and print the variance of <tt>traveltime</tt>.
#
# <font color="#6AA74F" size='3'>**3**&nbsp;&nbsp; </font>We can also define custom functions to apply to groups. Let's say we want to find students with more than 10 absences, and then find the group having more of these students. Define a function that does the following:
#  * Takes a series as input
#  * Calculates which values are greater than 10
#  * Returns the number of values that are greater than 10
# Put the column <tt>absences</tt> in that function to check if it is working.
#
# <font color="#6AA74F" size='4'>**4**&nbsp;&nbsp; </font>Group by <tt>address</tt> and use <tt>agg</tt> to apply the user-defined function in #3 to the <tt>absences</tt> column. Print the result to see which group of students has more students with more than 10 absences.

# %% [markdown]
# <font size='2' color="#A7AFBC">**EXPECTED OUTPUT**</font>
# ![Screen Shot 2021-10-21 at 13.59.38-min.png](data:image/png;base64,...)

# %% [markdown]
# #### <font size='5'>2.4 &nbsp;Concatenate, Join, Merge</font>

# %% [markdown]
# <font color="#6AA74F" size='3'>**1**&nbsp;&nbsp; </font>Load <tt>gp_data.csv</tt> and <tt>ms_data.csv</tt> then concatenate them as a new DataFrame. Print the shape of each DataFrame.
#
# <font color="#6AA74F" size='3'>**2**&nbsp;&nbsp; </font>Using <tt>concat</tt>, combine the first and last five rows of the DataFrame. Print the result.
#
# <font color="#6AA74F" size='3'>**3**&nbsp;&nbsp; </font>Load <tt>gp_grades.csv</tt> and <tt>ms_grades.csv</tt> then concatenate them as a new DataFrame. Print the shape of each DataFrame.
#
# <font color="#6AA74F" size='3'>**4**&nbsp;&nbsp; </font>Finally, use an inner join to combine the data from #1 and #3. Print the first and last five rows. Also, print it shape.

# %% [markdown]
# <font size='2' color="#A7AFBC">**EXPECTED OUTPUT**</font>
# ![Screen Shot 2021-10-21 at 13.59.51-min.png](data:image/png;base64,...)

# %% [markdown]
# ### <font size='6'>**Lesson 3**&nbsp;&nbsp;</font><font color="#EDF2F8" size='6'>⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼</font>

# %% [markdown]
# Data can be collected from many different sources, and the amount, type, and format of data can vary from source to source. Before we can analyze or use this data, we will need to clean the data so that all types, scales, and units match, and handle missing data. In this lesson, we will cover the above topics.
#
# We will use a dataset collected in 2019 that contains information on cars, including performance specs and used and new sale prices.

# %% [markdown]
# #### <font size='5'>3.1 &nbsp;Arithmetic Operations on Dataframe</font>

# %% [markdown]
# First, load the data from <tt>car_train_data.csv</tt>. You can set the index column to 0.
#
# Imagine you are contracted by an American company to perform some data preprocessing. Your tasks include creating some new columns based on old ones, as well as converting units from the metric system.
#
# <font color="#6AA74F" size='3'>**1**&nbsp;&nbsp; </font>Create a new column <tt>Age</tt> that is the car's age in years.
#  * This can be calculated from the year the data was collected (2019) plus 1 minus the car's <tt>Year</tt>.
#  * Print the first 10 rows.
#
# <font color="#6AA74F" size='3'>**2**&nbsp;&nbsp; </font>Create a <tt>Miles_Driven</tt> column from <tt>Kilometers_Driven</tt> (1 km = 0.6124 miles). Print the first 5 rows.
# Afterwards, drop the original <tt>Kilometers_Driven</tt> column.
#
# <font color="#6AA74F" size='3'>**3**&nbsp;&nbsp; </font>Create a new column <tt>Miles_Driven_Per_Year</tt>. This is <tt>Miles_Driven</tt> divided by <tt>Age</tt>. Print the first 5 rows.
#
# <font color="#6AA74F" size='3'>**4**&nbsp;&nbsp; </font>Print <tt>Year, Age, Miles_Driven,</tt> and <tt>Miles_Driven_Per_Year</tt> for rows 60 to 70.

# %% [markdown]
# <font size='2' color="#A7AFBC">**EXPECTED OUTPUT**</font>
# ![Screen Shot 2021-10-21 at 14.00.09-min.png](data:image/png;base64,...)

# %% [markdown]
# #### <font size='5'>3.2 &nbsp;Handling Missing Data</font>

# %% [markdown]
# You may have noticed that some data is missing. The customer would like to know which columns originally contain missing data, but then have any rows that are missing data removed.
#
# <font color="#6AA74F" size='3'>**1**&nbsp;&nbsp; </font>Create a binary array for columns that contain at least one missing value. Print the names of the columns that have missing values.
#
# <font color="#6AA74F" size='3'>**2**&nbsp;&nbsp; </font>Actually, the customer doesn't care if there is missing data in <tt>Mileage</tt> or <tt>Seats</tt>. Fill NA values in those columns with 0. To check, make a new DataFrame consisting the rows with <tt>Mileage</tt> is 0 or <tt>Seats</tt> is 0. Print the last 15 rows of that DataFrame.
#
# <font color="#6AA74F" size='3'>**3**&nbsp;&nbsp; </font>See how the DataFrame changes after filtering NA values:
#  * Print the shape of the original DataFrame.
#  * Remove rows with NA values.
#  * Print the shape of the new DataFrame with no missing values.

# %% [markdown]
# <font size='2' color="#A7AFBC">**EXPECTED OUTPUT**</font>
# ![Screen Shot 2021-10-21 at 14.00.30-min.png](data:image/png;base64,...)

# %% [markdown]
# #### <font size='5'>3.3 &nbsp;Discretization&nbsp;</font>

# %% [markdown]
# We may not always need continuous values for a variable. Discretization is the process of converting continuous values into a certain number of categories. The customer has requested that <tt>Miles_Driven_Per_Year</tt> be converted to three discrete categories.
#
# <font color="#6AA74F" size='3'>**1**&nbsp;&nbsp; </font>Filter only the data with <tt>Miles_Driven_Per_Year</tt> less than 10000.
# Print the shape of it. Also, print the first 5 rows of <tt>Miles_Driven_Per_Year</tt>.
#
# <font color="#6AA74F" size='3'>**2**&nbsp;&nbsp; </font>
#  Then, make a column <tt>Usage_Per_Year</tt> from <tt>Miles_Driven_Per_Year</tt> by discretizing the values into three bins of same range. The names of the categories should be <tt>Low, Medium,</tt> and <tt>High</tt>. Print the range and size of each bins.
#
# <font color="#6AA74F" size='3'>**3**&nbsp;&nbsp; </font>Print the first 5 rows of  <tt>Miles_Driven_Per_Year</tt> and <tt>Usage_Per_Year</tt>.
#
# <font color="#6AA74F" size='3'>**4**&nbsp;&nbsp; </font>Do the same as in #1, but instead of equally sized categories, create categories that have the same number of points per category.
#
# <font color="#6AA74F" size='3'>**5**&nbsp;&nbsp; </font>Make a new column <tt>Usage_Per_Year_Cat</tt>. This is the same bin as #2 but with categories should be <tt>Low, Medium,</tt> and <tt>High</tt> instead of range. Print the first 5 rows of <tt>Miles_Driven_Per_Year</tt>, <tt>Usage_Per_Year</tt>, and <tt>Usage_Per_Year_Cat</tt>.

# %% [markdown]
# <font size='2' color="#A7AFBC">**EXPECTED OUTPUT**</font>
# ![Screen Shot 2021-10-21 at 14.00.53-min.png](data:image/png;base64,...)

# %% [markdown]
# #### <font size='5'>3.4 &nbsp;Statistical Methods</font>

# %% [markdown]
# <font color="#6AA74F" size='3'>**1**&nbsp;&nbsp; </font>Save the min, max, mean, and standard deviation values of <tt>Price</tt> in variables <tt>min_Price, max_Price, mean_Price,</tt> and <tt>std_Price</tt>, respectively. Then, print them.
#
# <font color="#6AA74F" size='3'>**2**&nbsp;&nbsp; </font>We would like to normalize the <tt>Price</tt> using linear scaling. Make a new column <tt>Price_Norm_Linear</tt> using the following formula:<br> <tt>( Price - min_Price ) / ( max_Price - min_Price )</tt><br>
# Print the max and min of that new column. Also print first 5 rows of <tt>Price</tt> and <tt>Price_Norm_Linear</tt>.
#
# <font color="#6AA74F" size='3'>**3**&nbsp;&nbsp; </font>Let's do another Normalization using Z-score. Make a new column <tt>Price_Norm_ZScore</tt> using the following formula:<br> <tt>( Price - mean_Price ) / std_Price </tt><br>
# Save the mean and standard deviation in a variable then print them (show only 1 decimal place). Also print first 5 rows of <tt>Price</tt> and <tt>Price_Norm_ZScore</tt>.

# %% [markdown]
# <font size='2' color="#A7AFBC">**EXPECTED OUTPUT**</font>
# ![Screen Shot 2021-10-21 at 14.01.10-min.png](data:image/png;base64,...)

# %% [markdown]
# #### <font size='5'>3.5 &nbsp;Filtering and Transformation</font>

# %% [markdown]
# The customer would like to know which locations have cars with an average price that is higher than the average price for all cars.
#
# <font color="#6AA74F" size='3'>**1**&nbsp;&nbsp; </font>Print the mean of <tt>Price</tt> and also the mean for each Location.
#
# <font color="#6AA74F" size='3'>**2**&nbsp;&nbsp; </font>Get the groups whose mean <tt>Price</tt> is higher than the mean <tt>Price</tt> of all locations. Print all <tt>Location</tt> with mean higher than the mean of all <tt>Price</tt>.
#
# <font color="#6AA74F" size='3'>**3**&nbsp;&nbsp; </font>Get all the data where the mean <tt>Price</tt> of its <tt>Location</tt> is higher than 10. Save it in a new DataFrame. Then, print its shape and the first 10 rows of <tt>Location</tt> and <tt>Price</tt> of that dataset.

# %% [markdown]
# <font size='2' color="#A7AFBC">**EXPECTED OUTPUT**</font>
# ![Screen Shot 2021-10-21 at 14.01.38-min.png](data:image/png;base64,...)

# %% [markdown]
# ### <font size='6'>**Lesson 4**&nbsp;&nbsp;</font><font color="#EDF2F8" size='6'>⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼</font>

# %% [markdown]
# <font size='3' color="#bb2222">**!**</font>&nbsp;&nbsp;<font size='2'>**To retrieve the necessary data, please run the following code first.**</font></font><br>

# %%
student_data = pd.concat([
    pd.read_csv("gp_data.csv", sep=";", index_col="student_id"),
    pd.read_csv("ms_data.csv", sep=";", index_col="student_id")])
student_grades = pd.concat([
    pd.read_csv("gp_grades.csv", sep=";", index_col="student_id"),
    pd.read_csv("ms_grades.csv", sep=";", index_col="student_id")])
student_df = student_data.join(student_grades, how="inner")

car_df = pd.read_csv("car_train_data.csv", index_col=0)
car_df = car_df.dropna()

# %% [markdown]
# #### <font size='5'>4.1 &nbsp;Introduction to Matplotlib</font>

# %% [markdown]
# <font color="#6AA74F" size='3'>**1**&nbsp;&nbsp; </font>Plot a sine function from 0 to 2π. (For sine, see [here](https://numpy.org/doc/stable/reference/generated/numpy.sin.html). For π, see [here](https://numpy.org/doc/stable/reference/constants.html?highlight=pi#numpy.pi))
#
# <font color="#6AA74F" size='3'>**2**&nbsp;&nbsp; </font>
# Plot a cosine function from 0 to 2π. Put them together with plot in no.1, sharing the same x axis. Set <tt>figsize=(6,3)</tt>
#
# <font color="#6AA74F" size='3'>**3**&nbsp;&nbsp; </font>Repeat the process in no.2. Also, do the followings:
# * Change the color of the sine line to red and
# linestyle to "-.".
# * Change the color of the cosine line to green and linestyle "--".
# * Set <tt>figsize=(6,3)</tt>
#
# <font color="#6AA74F" size='3'>**4**&nbsp;&nbsp; </font>Repeat the process in no.3. Also, do the followings:
# * Change the xticks to range from [0, 2π] with intervals of 0.5π.
# * Change the yticks to range from [-1, 1] with intervals of 0.5.
# * Set the xlabels to 0.5π, 1.0π, 1.5π, etc. Don't forget to divide the tick by <tt>np.pi</tt> to get the right label.
# * Set <tt>figsize=(6,3)</tt>
# * Add the grid to each plot using the following method: <tt>ax.grid(True)</tt>
# * Add the appropriate title for each plot and the whole figure.

# %% [markdown]
# <font size='2' color="#A7AFBC">**EXPECTED OUTPUT**</font>
# ![Screen Shot 2021-10-21 at 14.05.49-min.png](data:image/png;base64,...)

# %% [markdown]
# #### <font size='5'>4.2 &nbsp;Plotting with Pandas</font>
#
# For the following questions, use <tt>student_df</tt> DataFrame given in the beginning of Lesson 4 Practice.
#
# <font color="#6AA74F" size='3'>**1**&nbsp;&nbsp; </font> Plot a kernel density estimate (kind="kde") of <tt>absences</tt> . The title should be <tt>Absences</tt>, and there should be no legend.
#
# <font color="#6AA74F" size='3'>**2**&nbsp;&nbsp; </font>Plot boxplots (kind="box") for <tt>G1, G2,</tt> and <tt>G3</tt>. Set the title to <tt>Grades</tt>.
#
# <font color="#6AA74F" size='3'>**3**&nbsp;&nbsp; </font>Plot a histogram (kind="hist") of <tt>studytime</tt> . The title should be <tt>Studytime</tt>, and there should be no legend.
#
# <font color="#6AA74F" size='3'>**4**&nbsp;&nbsp; </font>Create a figure with one row and three columns. Redo no.1, 2, 3 and put them in appropriate axes. Set <tt>figsize=(12,5)</tt>

# %% [markdown]
# <font size='2' color="#A7AFBC">**EXPECTED OUTPUT**</font>
# ![image.png](data:image/png;base64,...)
# ![Screen Shot 2021-10-21 at 14.10.33-min.png](data:image/png;base64,...)

# %% [markdown]
# #### <font size='5'>4.3 &nbsp;Various Styles of Visualization</font>
#
# For the following questions, use <tt>car_df</tt> DataFrame given in the beginning of Lesson 4.
#
# <font color="#6AA74F" size='3'>**1**&nbsp;&nbsp; </font>Create a line plot of the SUM of <tt>Kilometers_Driven</tt> per year. Change the xtick into only even-numbered year from 2002 until 2020.
#
# <font color="#6AA74F" size='3'>**2**&nbsp;&nbsp; </font>Create a pie chart for <tt>Fuel_Type</tt>. The format should be similar as in the expected output.
#
# <font color="#6AA74F" size='3'>**2**&nbsp;&nbsp; </font>Create a pie chart for the total <tt>Price</tt> divided by the <tt>Location</tt>: Southern India cities <tt>('Chennai', 'Bangalore', 'Coimbatore', 'Chennai', 'Kochi', 'Hyderabad')</tt> and others. The format should be similar as in the expected output.

# %% [markdown]
# <font size='2' color="#A7AFBC">**EXPECTED OUTPUT**</font>
# ![Screen Shot 2021-10-21 at 14.11.15-min.png](data:image/png;base64,...)

# %% [markdown]
# #### <font size='5'>4.4 &nbsp;Advanced Filtering </font>
# For the following questions, use <tt>car_df</tt> DataFrame given in the beginning of Lesson 4.
#
# <font color="#6AA74F" size='3'>**1**&nbsp;&nbsp; </font> Make a new DataFrame containing all <tt>Location</tt> of <tt>Hyderabad, Kochi,</tt> and <tt>Pune</tt> with <tt>Year</tt> between 2011 and 2018. From the filtered data, print the first 10 rows of <tt>Location</tt> and <tt>Year</tt>.
#
# <font color="#6AA74F" size='3'>**2**&nbsp;&nbsp; </font> Group the DataFrame in #1 by Location and Year and print the min of <tt>Price</tt> for those group.
#
# <font color="#6AA74F" size='3'>**3**&nbsp;&nbsp; </font> Make a pivot table with <tt>Year</tt> as the index, <tt>Location</tt> as the columns, and max of <tt>Price</tt> for those group as the values.
#
# <font color="#6AA74F" size='3'>**4**&nbsp;&nbsp; </font> Using the pivot table in no.3, make a 2x2 subplot consisting of a line graph, bar graph, stacked bar graph, and stacked ratio graph. Use <tt>figsize=(12,8)</tt>
#
# <font color="#6AA74F" size='3'>**5**&nbsp;&nbsp; </font> Using the filtered data in no.1, make 3 subplots consisting of histograms of the Price with bin size 10, 15, and 20. Use <tt>figsize=(12,4)</tt>

# %% [markdown]
# <font size='2' color="#A7AFBC">**EXPECTED OUTPUT**</font>
# ![Screen Shot 2021-10-21 at 14.11.43-min.png](data:image/png;base64,...)
# ![Screen Shot 2021-10-21 at 14.12.15-min.png](data:image/png;base64,...)

# %% [markdown]
# #### <font size='5'>4.5 &nbsp;Multiple Plots with Seaborn</font>

# %% [markdown]
# <font color="#6AA74F" size='3'>**1**&nbsp;&nbsp; </font> Using <tt>car_df</tt>, filter the data so it only contains <tt>Year</tt> from 2012 to 2019.
# Make a bar plot for **count** of <tt>Price</tt> vs <tt>Year</tt> for each Location.
#
# <font color="#6AA74F" size='3'>**2**&nbsp;&nbsp; </font> Using the filtered data from no. 1, make a line plot for **mean** of <tt>Price</tt> vs <tt>Year</tt> for each Location. Hint: use <tt>relplot</tt> instead of <tt>catplot</tt> for continuous data.
#
# <font color="#6AA74F" size='3'>**3**&nbsp;&nbsp; </font> Using the filtered data from no. 1, make three boxplot for the <tt>Location</tt> of "Hyderabad", "Kochi", and "Pune". The y-axis should be the <tt>Price</tt>.

# %% [markdown]
# <font size='2' color="#A7AFBC">**EXPECTED OUTPUT**</font>
# ![Screen Shot 2021-10-21 at 14.12.48-min.png](data:image/png;base64,...)
# ![Screen Shot 2021-10-21 at 14.13.42-min.png](data:image/png;base64,...)

# %% [markdown]
# ### <font size='6'>**Lesson 5**&nbsp;&nbsp;</font><font color="#EDF2F8" size='6'>⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼⎼</font>

# %% [markdown]
# <font size='3' color="#bb2222">**!**</font>&nbsp;&nbsp;<font size='2'>**To retrieve the necessary data, please run the following code first.**</font></font><br>

# %%
student_data = pd.concat([
    pd.read_csv("gp_data.csv", sep=";", index_col="student_id"),
    pd.read_csv("ms_data.csv", sep=";", index_col="student_id")])
student_grades = pd.concat([
    pd.read_csv("gp_grades.csv", sep=";", index_col="student_id"),
    pd.read_csv("ms_grades.csv", sep=";", index_col="student_id")])
student_df = student_data.join(student_grades, how="inner").reset_index(drop=False)

car_df = pd.read_csv("car_train_data.csv", index_col=0)
car_df = car_df.dropna()

car_df_test = pd.read_csv("car_test_data.csv", index_col=0)

# %% [markdown]
# #### <font size='5'>5.1 &nbsp;Preprocessing with Sklearn</font>
# <font color="#6AA74F" size='3'>**1**&nbsp;&nbsp; </font>Using <tt>student_df</tt>, make a boxplot for the column <tt>G3</tt>.
#
# <font color="#6AA74F" size='3'>**2**&nbsp;&nbsp; </font>Create a new column called "G3_Standard". This is the G3 column that already standardized using StandardScaler. Print the first 5 rows of <tt>G3</tt> and <tt>G3_Standard</tt>.
#
# <font color="#6AA74F" size='3'>**3**&nbsp;&nbsp; </font>Print the mean and standard deviation of <tt>G3</tt> and <tt>G3_Standard</tt>. Plot a boxplot of <tt>G3_Standard</tt>.
#
# <font color="#6AA74F" size='3'>**4**&nbsp;&nbsp; </font>Create a new column called "G3_MinMax". This is the G3 column that already standardized using MinMaxScaler. Print the first 5 rows of <tt>G3</tt> and <tt>G3_MinMax</tt>.
#
# <font color="#6AA74F" size='3'>**5**&nbsp;&nbsp; </font>Print the min and max of <tt>G3</tt> and <tt>G3_MinMax</tt>. Plot a boxplot of <tt>G3_MinMax</tt>.
#
# <font color="#6AA74F" size='3'>**6**&nbsp;&nbsp; </font> Make a subplot of 3 rows with <tt>figsize=(6,8)</tt> and remake the boxplot in no 1, 3, and 5 in that subplot.

# %% [markdown]
# <font size='2' color="#A7AFBC">**EXPECTED OUTPUT**</font>
# ![Screen Shot 2021-10-21 at 14.14.16-min.png](data:image/png;base64,...)
# ![Screen Shot 2021-10-21 at 14.14.51-min.png](data:image/png;base64,...)

# %% [markdown]
# #### <font size='5'>5.2 &nbsp;Linear Regression</font>

# %% [markdown]
# We will try to predict the <tt>Price</tt> of a car.
#
# <font color="#6AA74F" size='3'>**1**&nbsp;&nbsp; </font> Copy and paste this code (to clean some columns with units and convert it to numerical data set)<br>
# <tt>to_num_list = ["Engine", "Power", "New_Price", "Price"]</tt><br>
# <tt>car_df_new = car_df[to_num_list].replace(" .*", "", regex=True).astype("float")</tt><br>
# Filter <tt>car_df</tt> so it only contains <tt>Price < 100</tt> and <tt>New_Price > 2</tt>. Then,
# Print the first 5 rows of that new DataFrame.
#
# <font color="#6AA74F" size='3'>**2**&nbsp;&nbsp; </font>Make a linear regression model from <tt>car_df_new</tt> using <tt>Price</tt> as the target (<tt>y</tt>) and the other columns as the attributes (<tt>X</tt>).
# * Then, make a subplot of 3 rows and 1 column with <tt>figsize=(4,12)</tt>.
# * Make 3 plots of the regression line of <tt>Price</tt> vs <tt>Engine</tt>, <tt>Power</tt>, and <tt>New_Price</tt> and put them in the subplot. Set <tt>marker='+'</tt> in each plot.
#
# <font color="#6AA74F" size='3'>**3**&nbsp;&nbsp; </font>Print out the coefficients value for all the attributes.
#
# <font color="#6AA74F" size='3'>**4**&nbsp;&nbsp; </font>Print out the regression score of your model.

# %% [markdown]
# <font size='2' color="#A7AFBC">**EXPECTED OUTPUT**</font>
# ![Screen Shot 2021-10-21 at 14.17.38-min.png](data:image/png;base64,...)
# ![Screen Shot 2021-10-21 at 14.17.58-min.png](data:image/png;base64,...)

# %% [markdown]
# #### <font size='5'>5.3 &nbsp;Logistic Regression</font>

# %% [markdown]
# We will try to predict whether a student is failing or not based on their personal situation.
#
# <font color="#6AA74F" size='3'>**1**&nbsp;&nbsp; </font>[Set the index](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.set_index.html) of <tt>student_df</tt> to be the column <tt>student_id</tt>. Create a new binary label called <tt>G3_binary</tt> from <tt>G3</tt> with the following conditions: if <tt>G3</tt> is less than 12, the value is 0, otherwise the value is 1. You can think of this as pass/fail indicator. Print the first 5 rows of <tt>G3</tt> and <tt>G3_binary</tt>
#
# <font color="#6AA74F" size='3'>**2**&nbsp;&nbsp; </font>Convert all the <tt>object</tt>-type columns into dummy variables. Save them in a variable called <tt>object_dummy</tt>. Print all the columns name.
#
# <font color="#6AA74F" size='3'>**3**&nbsp;&nbsp; </font>Join <tt>object_dummy</tt> with all the numerical columns. Also, drop the columns <tt>G1</tt>, <tt>G2</tt>, and <tt>G3</tt>. Save them in a variable called <tt>student_new</tt>. Print all the columns name.
#
# <font color="#6AA74F" size='3'>**4**&nbsp;&nbsp; </font>Split <tt>student_new</tt> into two parts: Row 1-500 as <tt>stu_train</tt> and Row 501-649 as <tt>stu_test</tt>. Print the first 5 rows of each.
#
# <font color="#6AA74F" size='3'>**5**&nbsp;&nbsp; </font>
# Make a logistic regression model from <tt>stu_train</tt> using <tt>G3_binary</tt> as the target (<tt>y</tt>) and the other columns as the attributes (<tt>X</tt>).
# * Use <tt>LogisticRegression(solver='liblinear')</tt> to prevent warning.
# * Test the model using <tt>stu_test</tt>, save the prediction result in a new column <tt>G3_pred</tt>.
# * Print the first 10 rows of <tt>G3_binary</tt> and <tt>G3_pred</tt> of <tt>stu_test</tt>.
#
# <font color="#6AA74F" size='3'>**6**&nbsp;&nbsp; </font>Print out the accuracy score of the model.

# %% [markdown]
# <font size='2' color="#A7AFBC">**EXPECTED OUTPUT**</font>
# ![Screen Shot 2021-10-21 at 14.18.24-min.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### <font size='5'>5.4 &nbsp;Classification Methods</font>

# %% [markdown]
# Write the same code as 5.3 and replace the model to be as follows:
#
# <font color="#6AA74F" size='3'>**1**&nbsp;&nbsp; </font>Use <tt>KNeighborsClassifier</tt>. Set <tt>k</tt> to 2.
#
# <font color="#6AA74F" size='3'>**2**&nbsp;&nbsp; </font>Use <tt>DecisionTreeClassifier</tt>
#
# <font color="#6AA74F" size='3'>**3**&nbsp;&nbsp; </font>Use <tt>AdaBoostClassifier</tt> with <tt>n_estimators=5</tt>

# %% [markdown]
# <font size='2' color="#A7AFBC">**EXPECTED OUTPUT**</font>
# ![Screen Shot 2021-10-21 at 14.21.04-min.png](data:image/png;base64,...)

# %% [markdown]
# #### <font size='5'>5.5 &nbsp;Clustering Methods</font>

# %% [markdown]
# <font color="#6AA74F" size='3'>**1**&nbsp;&nbsp; </font>Get all the numerical columns from <tt>student_df</tt>.
# Print the columns name of the new dataset.
#
# <font color="#6AA74F" size='3'>**2**&nbsp;&nbsp; </font>Scale the data using <tt>scale</tt> then perform a PCA. Print the explained variance ratio. (add <tt>.round(3)</tt>)
#
# <font color="#6AA74F" size='3'>**3**&nbsp;&nbsp; </font>Convert the PCA result to a DataFrame and make a scatter plot of PCA column 0 and PCA column 1.
# * Make a new <tt>G3_binary</tt> column (same as 5.3 no.1) and use that as the color of the scatter plot. (For changing color, you can add an argument <tt>c=student_df['G3_binary'].astype('category').cat.codes</tt> to the plot. Black means success, White means failed.)
# * Change the background color to grey (You can use <tt>plt.rcParams['axes.facecolor'] = '0.8'</tt>)
#
# <font color="#6AA74F" size='3'>**4**&nbsp;&nbsp; </font>Perform clustering using KMeans with n_clusters=2.
#
# <font color="#6AA74F" size='3'>**5**&nbsp;&nbsp; </font>Perform clustering using DBSCAN with eps=2.3, min_samples=6
#
#
# <font color="#6AA74F" size='3'>**6**&nbsp;&nbsp; </font>We don't know what the clusters that the algorithms found are, but we can look at our data again and see if there are any similarities. Plot the output of PCA again, but this time:
# * Make a new <tt>G3_binary</tt> column (same as 5.3 no.1) and use that as the color of the scatter plot. (For changing color, you can add an extra argument <tt>c=student_df['G3_binary'].map({0:'#1E77B4',1:'#FF7F0F'})</tt>)
# * Do you see any similarities with the clustering result?

# %% [markdown]
# <font size='2' color="#A7AFBC">**EXPECTED OUTPUT**</font>
# ![Screen Shot 2021-10-21 at 14.22.34-min.png](data:image/png;base64,...)
# ![Screen Shot 2021-10-21 at 14.24.23-min.png](data:image/png;base64,...)
